# %%
x = int(input())

rice = 100
water = 140
egg = 50
salt = 3
oil = 5

total = rice + water + egg + salt + oil

ra_rice = rice/total
ra_water = water/total
ra_egg = egg/total
ra_salt = salt/total
ra_oil = oil/total

am_rice = ra_rice * x
am_water = ra_water * x
am_egg = ra_egg * x
am_salt = ra_salt * x
am_oil = ra_oil * x

print(am_rice,am_water, am_egg, am_salt, am_oil)
# Out:
# 134.2281879194631 187.91946308724832 67.11409395973155 4.026845637583892 6.7114093959731544

# %%
n = float(input())
i = 0 
s = 0

while i <= n:
    s = s + (4*(-1)**i)/(2*i + 1)
    i = i + 1

pi = s
print(pi)
# Out:
# 3.141612653189785

# %%
x = float(input())
y = float(input())
z = float(input())\

if x > y and x > z :
    if y > z:
        print(z,y,x)
    else:
        print(y,z,x)
elif y > z :
    if x > z:
        print(y,x,z)
    else:
        print(y,z,x)
else:
    if x > y:
        print(z,x,y)
    else:
        print(z,y,x)
# Out:
# -111.0 12.55 687.0

# %%
a = float(input())
b = float(input())
if a > b:
    D = a - b
else:
    D = b - a

d = D/93

x = a

while x <= b:
    f = x**2 + 3*x + 2
    print(a,b,x,f)
    x = x + d
# Out:
# -2.1 -1.9 -2.1 0.10999999999999943
# -2.1 -1.9 -2.0978494623655917 0.10742397965082695
# -2.1 -1.9 -2.0956989247311832 0.10485720892588724
# -2.1 -1.9 -2.093548387096775 0.10229968782518206
# -2.1 -1.9 -2.0913978494623664 0.09975141634871143
# -2.1 -1.9 -2.089247311827958 0.09721239449647445
# -2.1 -1.9 -2.0870967741935496 0.09468262226847113
# -2.1 -1.9 -2.084946236559141 0.09216209966470235
# -2.1 -1.9 -2.0827956989247327 0.08965082668516722
# -2.1 -1.9 -2.0806451612903243 0.08714880332986663
# -2.1 -1.9 -2.078494623655916 0.0846560295987997
# -2.1 -1.9 -2.0763440860215074 0.08217250549196642
# -2.1 -1.9 -2.074193548387099 0.07969823100936768
# -2.1 -1.9 -2.0720430107526906 0.0772332061510026
# -2.1 -1.9 -2.069892473118282 0.07477743091687117
# -2.1 -1.9 -2.0677419354838737 0.07233090530697428
# -2.1 -1.9 -2.0655913978494653 0.06989362932131193
# -2.1 -1.9 -2.063440860215057 0.06746560295988324
# -2.1 -1.9 -2.0612903225806485 0.0650468262226882
# ...
